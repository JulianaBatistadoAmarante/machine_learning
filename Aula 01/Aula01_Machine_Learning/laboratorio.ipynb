# %% [markdown]
# # Aula 01 - Machine Learning
# © @karizeviecelli - 2026

# %%
import pandas as pd

# %%
df=pd.read_csv('alunos.csv')
df

# %%
df.head()

# %%
df.shape

# %%
df.columns

# %%
df.dtypes

# %%
df.info()

# %%
df.describe()
